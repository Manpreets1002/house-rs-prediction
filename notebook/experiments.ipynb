# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:\\Users\\HP\\Github\\house-rs-prediction\\data\\india_housing_prices.csv")
df.head()
# Out:
#    ID        State      City      Locality      Property_Type  BHK  \
# 0   1   Tamil Nadu   Chennai   Locality_84          Apartment    1
# 1   2  Maharashtra      Pune  Locality_490  Independent House    3
# 2   3       Punjab  Ludhiana  Locality_167          Apartment    2
# 3   4    Rajasthan   Jodhpur  Locality_393  Independent House    2
# 4   5    Rajasthan    Jaipur  Locality_466              Villa    4
#
#    Size_in_SqFt  Price_in_Lakhs  Price_per_SqFt  Year_Built  ...  \
# 0          4740          489.76            0.10        1990  ...
# 1          2364          195.52            0.08        2008  ...
# 2          3642          183.79            0.05        1997  ...
# 3          2741          300.29            0.11        1991  ...
# 4          4823          182.90            0.04        2002  ...
#
#   Age_of_Property  Nearby_Schools  Nearby_Hospitals  \
# 0              35              10                 3
# 1              17               8                 1
# ...

# %%
df.columns
# Out:
# Index(['ID', 'State', 'City', 'Locality', 'Property_Type', 'BHK',
#        'Size_in_SqFt', 'Price_in_Lakhs', 'Price_per_SqFt', 'Year_Built',
#        'Furnished_Status', 'Floor_No', 'Total_Floors', 'Age_of_Property',
#        'Nearby_Schools', 'Nearby_Hospitals', 'Public_Transport_Accessibility',
#        'Parking_Space', 'Security', 'Amenities', 'Facing', 'Owner_Type',
#        'Availability_Status'],
#       dtype='object')

# %%
df.drop("ID", axis=1, inplace=True)
df.head()
# Out:
#          State      City      Locality      Property_Type  BHK  Size_in_SqFt  \
# 0   Tamil Nadu   Chennai   Locality_84          Apartment    1          4740
# 1  Maharashtra      Pune  Locality_490  Independent House    3          2364
# 2       Punjab  Ludhiana  Locality_167          Apartment    2          3642
# 3    Rajasthan   Jodhpur  Locality_393  Independent House    2          2741
# 4    Rajasthan    Jaipur  Locality_466              Villa    4          4823
#
#    Price_in_Lakhs  Price_per_SqFt  Year_Built Furnished_Status  ...  \
# 0          489.76            0.10        1990        Furnished  ...
# 1          195.52            0.08        2008      Unfurnished  ...
# 2          183.79            0.05        1997   Semi-furnished  ...
# 3          300.29            0.11        1991        Furnished  ...
# 4          182.90            0.04        2002   Semi-furnished  ...
#
#    Age_of_Property  Nearby_Schools  Nearby_Hospitals  \
# ...

# %%
df.isna().sum()
# Out:
# State                             0
# City                              0
# Locality                          0
# Property_Type                     0
# BHK                               0
# Size_in_SqFt                      0
# Price_in_Lakhs                    0
# Price_per_SqFt                    0
# Year_Built                        0
# Furnished_Status                  0
# Floor_No                          0
# Total_Floors                      0
# Age_of_Property                   0
# Nearby_Schools                    0
# Nearby_Hospitals                  0
# Public_Transport_Accessibility    0
# Parking_Space                     0
# Security                          0
# Amenities                         0
# Facing                            0
# Owner_Type                        0
# Availability_Status               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)
